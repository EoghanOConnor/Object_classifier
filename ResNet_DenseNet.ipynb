# %% [markdown]
# **Name:** Eoghan O'Connor <br>

# %% [markdown]
# # **NOTE** Ive made a ResNet (87-88% accuracy) and DenseNet model (76-78% accuracy)

# %% [markdown]
# # Etivity 1: Deep Convolutional Neural Network on CIFAR-10 Dataset
#
# In this assignment, we will gain some practical experience of coding a deep convolutional neural network in Tensorflow. The simplest way to code a network is to use the High level Keras API within Tensorflow 2.5.
#
# ## (a) Introduction
#
#  In this assignment to reduce training time and computation, we will train our network using the simple [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.
# ![link text](https://paperswithcode.com/media/datasets/CIFAR-10-0000000431-b71f61c0_U5n3Glr.jpg)
#
# The goal of this Etivity is to build and train your own Deep Convolutional Neural Network. This notebook contains standard keras/Tensorflow code to perform data processing, training set up and testing metrics, as outlined in the steps below. This will allow you to focus on developing the architecture & code for your network.
#
# 1. Load Dataset - We will import the CIFAR-10 Dataset using the Tensorflow Data Set API.
# 2. Prepare Data - We will slightly modify the dataset before it is sent to the model for training.
# 3. Model Coding - We will write code to build the model using the Tensorflow keras API.
#   * **You will code your neural network model in this section**
# 4. Compile Model - We will complile the model and verify that it has been correctly constructed.
# 5. Train Model - We will train the model using the imported dataset.
# 6. Test Model - We test the model on the training data and obtain a classification report and confusion matrix.
#
# The principal resource for understanding the basics of how to code & train Deep Convolutional Neural Network architectures in Tensorflow/keras are the Tensorflow tutorials. Tutorials on [image classification](https://www.tensorflow.org/tutorials/images/classification) and [data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) are useful for this Etivity.

# %% [markdown]
# ## (b) Notes on Architecture selection & development
#
# A key task in this Etivity is selecting an appropriate architecture. You can base your archicture on any of the types seen in the lecture notes or published literature. It is however recommended to ensure you can get a standard CNN type architecture to successfully train before attempting a more complex architecture or adding further enhancements to your network to improve performance.
#    Many published networks are designed to work with larger sized input images (e.g. 224 x 224). Often large (e.g. 7 x 7) convolution kernels and pooling layers are first applied to the input image, which agressively reduce the spatial dimensions of the network. As the CIFAR-10 dataset only has 32 x 32 images, it is recommended that just an intial 3 x 3 convolution is applied to the input image (as shown in the figure below), which will preserve the spatial dimensions of the input, before any other layers are added. It is expected that as you add more layers to the network the spatial dimensions will reduce and there will also be a corresponding increase the number of channels of the output feature map. The architecture will end with a [global average pooling layer](https://arxiv.org/pdf/1312.4400.pdf) and a fully-connected layer (called a *dense* layer in Keras/Tensorflow) with softmax activation which gives us our 10 class predictions. A skeleton code has been provided for any general architure using this structure in section 3.
# ![link text](https://github.com/tonyscan6003/etivities/blob/main/Architecture_outline.jpg?raw=true)

# %% [markdown]
# #House Keeping

# %%
from __future__ import print_function

# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import GlobalAveragePooling2D,AveragePooling2D, Input, Flatten, Concatenate,  Add, MaxPooling2D, SpatialDropout2D, Reshape, Permute
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, Dense, Permute, multiply
from tensorflow.keras.layers import RandomFlip, RandomZoom, RandomTranslation


import numpy as np
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# To ensure this assignment runs as fast as possible, from the menu above select **Edit > Notebook settings** or **Runtime > Change runtime type** and select GPU as the Hardware accelerator option.
#
# Let's test that we are running using the GPU.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# #1. Load Dataset
#
# In this assignment, we will be using the [CIFAR-10 dataset](http://www.cs.toronto.edu/~kriz/cifar.htmlhttps://). CIFAR-10 is often used as a "Hello World" dataset that is often used to ensure a network architecture is working before moving on to training with more complex datasets.
#
# The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes (airplane, automobile, **bird**, cat, deer, dog, frog, horse, ship, truck), with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# We will use the [Tensorflow dataset](https://www.tensorflow.org/datasets/catalog/cifar10) API to download the CIFAR10 dataset.

# %%
batch_size = 32 # Default Batch size (can be adjusted)
H_trg =32       # Image Height (fixed)
W_trg =32       # image Width (fixed)

# Labels corresponding to categories
label_str = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We initally load the raw training/validation/test dataset
import tensorflow_datasets as tfds
ds,info= tfds.load("cifar10",with_info=True)

raw_train = tfds.load('cifar10', split='train[0%:90%]')
raw_val = tfds.load('cifar10', split='train[91%:100%]')
raw_test = tfds.load('cifar10', split='test')
# Out:
# Downloading and preparing dataset 162.17 MiB (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to ~/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/cifar10/3.0.2.incompleteAZNREQ/cifar10-train.tfrecord*...:   0%|          | 0/…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/cifar10/3.0.2.incompleteAZNREQ/cifar10-test.tfrecord*...:   0%|          | 0/1…
# Dataset cifar10 downloaded and prepared to ~/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# # 2. Prepare Data
#
# After importing raw datasets using tfds load, we create an input pipeline that processes & batches this data before it is supplied to the model for training using the virtual machine GPU.

# %%
def data_pipe(image,label):
  image = tf.image.convert_image_dtype(image, tf.float32) # Cast and normalize the image to [0,1]
  image = image-0.5
  label = tf.cast(label, tf.float32)
  return image,label

# %%
def gen_tr_datasets(src_dataset):    
    # Define Datasets 
    #src_dataset = src_dataset.shuffle(num_train_examples) 
    tr_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    tr_dataset = tr_dataset.map(data_pipe)
    tr_dataset = tr_dataset.batch(batch_size) 
    return tr_dataset

def gen_val_datasets(src_dataset): 
    # Define Datasets 
    test_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    test_dataset = test_dataset.map(data_pipe)
    test_dataset = test_dataset.batch(batch_size) 
    return test_dataset
# Generate the datasets
train_dataset = gen_tr_datasets(raw_train)
val_dataset = gen_val_datasets(raw_val)
test_dataset = gen_val_datasets(raw_test)

# %% [markdown]
# Plot some examples of the training dataset.

# %%
i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image, label in train_dataset.take(n_plots):  # Only take a single example
  axarr[i].imshow(image[0,:,:,:]+0.5)
  axarr[i].axis('off')
  axarr[i].title.set_text(label_str[int(label[0])])
  i = i+1

# %% [markdown]
# # 3. Model Coding
#
# In this section You may develop your own model architecture to perform image recognition with the CIFAR-10 Dataset.
#
# There are some recommendations and helper code in this section that you may choose use, or you can also use your own approach to creating your architecture.
#
# Please Leave a note at the end of the notebook explaining your approach/results for the e-moderator.

# %% [markdown]
#
# ## Note 1: Keras Function/Sequential API
#
# Within Keras there are two API's for coding network models: Sequential and functional. You may have already used the [seqential model](https://https://www.tensorflow.org/guide/keras/sequential_model) to code basic artifical neural networks. The [functional model](https://www.tensorflow.org/guide/keras/functional) is more general and enables us to include feedforward paths which are required to code more advanced networks such as ResNet or DenseNet. The functional API has been used to code the helper functions repeating unit/top level skeleton detailed below.
#
# ## Note 2: Repeating Unit
#
# In many Deep architectures there will often be a repeating unit(s) that is composed of a sequence of layers, for example Conv,ReLU & Batch Normalisation. Specific layers can be turned on or off as required. This also allows experimentation of the entire architecture with/without specific layers (e.g. Batch Normalisation)  You may wish to create other combinations of layers or additional repeating units depending on your architecture.
#
# In the code cell below we can see an example of a `repeat_unit` function where the number of kernel filters and kernel size is specified. Batch Normalisation and activation layers can be turned on/off as required.
#
#  * Convolutional Layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
#  * Batch Normalization layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#  * Activation layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)

# %%
# Example of a Basic Repeating unit

def repeat_unit(inputs, num_channels=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=False):
    """
    inputs: Input to repeat unit.
    num_channels: number of channels in convolution layer of repeat unit, nominally = 16
    kernel_size: number of kernels to use in convolution, nominally = 3
    strides: number of strides for kernel, nominally = 1
    activation: type of activation applied to output of convolution, nominally ReLU. 
    x = output of repeat_unit
    """
    conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides, padding='same',
                  kernel_initializer='he_normal')
    x = conv(inputs)
    
    if activation is not None:
        x = Activation(activation)(x)

    if batch_normalization:
        x = BatchNormalization()(x)

    return x

# %% [markdown]
# ## Note 3: Top Level
#
# In the code cell below, an incomplete skeleton function is provided for your top level.
# * This uses the Keras functional API
# * A single repeating unit which does not reduce the spatial dimensions of the input is placed at the top of the stack. You can change the number of channels/kernel size to suit your own architecture.
# * You can add your own layers/repeating units etc to build your own architecture with the function.
# * At the end of the stack we add a [global average pooling layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D) and fully connected [(Dense)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layer with softmax activation. (Alternatively to the Global Average pooling Dense layers can be used, this approach uses more parameter (memory) and is commonly seen in earlier Deeep Learning architectures such as AlexNet)

# %%
def block_type_a (x,num_ch):
    y = repeat_unit(inputs=x, num_channels=num_ch,
                    kernel_size=3, batch_normalization=True)
    ###Block 2
    y = repeat_unit(inputs=y, num_channels=num_ch, activation=None,
                    batch_normalization=True)
    x = Add()([x, y])
    x = Activation('relu')(x)
    return x

# %%
def block_type_b (x,num_ch):
    ##Conv 3x3 x M(stride=2) Batch Normalization relu
    y = repeat_unit(inputs=x, num_channels=num_ch, strides=2,
                      kernel_size=3, batch_normalization=True)
    ##Conv 3x3 x M(stride=2) Batch Normalization relu
    y = repeat_unit(inputs=y,kernel_size=3, activation=None,
                      num_channels=num_ch, batch_normalization=True)
    
    ##Conv 1x1 x M(stride=2) Batch Normalization relu
    x = repeat_unit(inputs=x,strides=2, kernel_size=1, activation=None,
                    num_channels=num_ch, batch_normalization=True)
    x = Add()([y, x])
    x = Activation('relu')(x)
    return x

# %%
def squeeze_excite_block(x,num_ch,ratio=16):
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    se_shape = (1, 1, num_ch)

    y = GlobalAveragePooling2D()(x)
    y = Reshape(se_shape)(y)
    y = Dense(num_ch // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(y)
    y = Dense(num_ch, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(y)

    if K.image_data_format() == 'channels_first':
        y = Permute((3, 1, 2))(y)

    x = multiply([x, y])
    return x

# %%
def network_top(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
    num_ch = 32  
    # Define input of model
    inputs = Input(shape=input_shape)

    # Add data augmentation as layers
    x = RandomFlip(mode = "horizontal")(inputs)

    # Add First repeating Unit
    x = repeat_unit(inputs=x, num_channels=num_ch,activation=None)
   ######## Add more layers/repeating units to build your Architecture here ##################
   
    drop_rate = .1
    ###Block 1 -2
    x = block_type_a (x,num_ch)
    x = SpatialDropout2D(drop_rate)(x)

    ###Block 3-4
    x = block_type_a (x,num_ch)
    x = SpatialDropout2D(drop_rate)(x)


    ###Block 5-6
    num_ch2 = 64
    x = block_type_b (x,num_ch2)
    x = SpatialDropout2D(drop_rate)(x)



    ###Block 7-8
    x = block_type_a (x,num_ch2)
    x = SpatialDropout2D(drop_rate)(x)

    ###Block 9-10
    num_ch3 = 128
    x = block_type_b (x,num_ch3)
    x = SpatialDropout2D(drop_rate)(x)



    ###Block 11 - 12
    x = block_type_a (x,num_ch3)
    x = SpatialDropout2D(drop_rate)(x)

    # Squeeze Excite
    x = squeeze_excite_block(x,num_ch3, ratio=16)

  #  Add final stages. (Ensure that you call the output of the very last layer outputs)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 4. Compile the Model
# Now that we have defined our functions to create the model, we'll instantiate the model and compile it.  Note that the compiling step in Keras, also configures the model for training. We define  loss function, the optimizer and metrics.
#
# Note the use here of [Sparse Categorical Crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy). This loss function allows us to input integer values for true classes. With the regular categorical cross entropy loss function the supplied labels must be frist converted to a one-hot representation,  but this special loss function allows us to avoid manually converting to the one-hot representation.

# %%
input_shape = (32,32,3)
model = network_top(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()

# Uncomment the following line to plot the model visually - warning this may be quite large!
keras.utils.plot_model(model, dpi=48)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  random_flip (RandomFlip)       (None, 32, 32, 3)    0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   896         ['random_flip[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 32)   9248        ['conv2d[0][0]']
#
#  activation (Activation)        (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['activation[0][0]']
#  alization)
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 32)   9248        ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 32)   0           ['conv2d[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 32)   0           ['add[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 32, 32, 32)  0           ['activation_1[0][0]']
#  out2D)
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 32)   9248        ['spatial_dropout2d[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 32)   0           ['conv2d_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 32)  128         ['activation_2[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 32)   9248        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 32)   0           ['spatial_dropout2d[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_3 (Activation)      (None, 32, 32, 32)   0           ['add_1[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 32, 32, 32)  0           ['activation_3[0][0]']
#  opout2D)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   18496       ['spatial_dropout2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 16, 16, 64)   0           ['conv2d_5[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 64)  256         ['activation_4[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 64)   2112        ['spatial_dropout2d_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 64)   0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_5 (Activation)      (None, 16, 16, 64)   0           ['add_2[0][0]']
#
#  spatial_dropout2d_2 (SpatialDr  (None, 16, 16, 64)  0           ['activation_5[0][0]']
#  opout2D)
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 64)   36928       ['spatial_dropout2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 16, 16, 64)   0           ['conv2d_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 64)  256         ['activation_6[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 16, 16, 64)   0           ['spatial_dropout2d_2[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 64)   0           ['add_3[0][0]']
#
#  spatial_dropout2d_3 (SpatialDr  (None, 16, 16, 64)  0           ['activation_7[0][0]']
#  opout2D)
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 128)    73856       ['spatial_dropout2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 8, 8, 128)    0           ['conv2d_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 128)   512         ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 128)    147584      ['batch_normalization_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 128)    8320        ['spatial_dropout2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 128)    0           ['batch_normalization_10[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 128)    0           ['add_4[0][0]']
#
#  spatial_dropout2d_4 (SpatialDr  (None, 8, 8, 128)   0           ['activation_9[0][0]']
#  opout2D)
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 128)    147584      ['spatial_dropout2d_4[0][0]']
#
#  activation_10 (Activation)     (None, 8, 8, 128)    0           ['conv2d_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 128)   512         ['activation_10[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    147584      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 128)    0           ['spatial_dropout2d_4[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  activation_11 (Activation)     (None, 8, 8, 128)    0           ['add_5[0][0]']
#
#  spatial_dropout2d_5 (SpatialDr  (None, 8, 8, 128)   0           ['activation_11[0][0]']
#  opout2D)
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['spatial_dropout2d_5[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 8)      1024        ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 128)    1024        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 8, 8, 128)    0           ['spatial_dropout2d_5[0][0]',
#                                                                   'dense_1[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['multiply[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 10)           1290        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 701,898
# Trainable params: 699,722
# Non-trainable params: 2,176
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Model Training
#
# We will now train the complied model on the cifar10 dataset using the tensorflow keras `model.fit` method.

# %%
epochs = 25
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=val_dataset)
# Out:
# 1407/1407 [==============================] - 35s 25ms/step - loss: 0.8996 - accuracy: 0.6844 - val_loss: 0.7385 - val_accuracy: 0.7373

# %% [markdown]
# We will plot the loss and accuracy for the training and validation data sets.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # 6. Model Testing
# We will iterate through the test data and analyse the results using tools from sklearn. We create a classification report, a confusion matrix and also plot a few examples from the test set.

# %% [markdown]
# Iterate through n_test batches and store the predicted and ground truth labels in numpy arrays.

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %% [markdown]
# Create and plot a confusion matrix.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %% [markdown]
# Generate & print the classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.84      0.69      0.76       337
#   automobile       0.85      0.90      0.88       338
#         bird       0.63      0.63      0.63       306
#          cat       0.57      0.54      0.55       323
#         deer       0.78      0.63      0.70       297
#          dog       0.58      0.73      0.65       325
#         frog       0.68      0.90      0.78       307
#        horse       0.86      0.69      0.76       317
#         ship       0.87      0.87      0.87       326
#        truck       0.83      0.82      0.82       324
#
#     accuracy                           0.74      3200
#    macro avg       0.75      0.74      0.74      3200
# weighted avg       0.75      0.74      0.74      3200

# %% [markdown]
# Plot some test images and predicted labels.

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1
# Out:
# (32, 10)
# (32,)
# Predictions:
#  [2 0 6 9 5 1 7 0 5 4 7 2 7 9 2 8 2 8 7 5 4 6 3 5 3 2 6 8 1 8 6 0]

# %%
def dense_unit(inputs, num_channels=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=True):
  """
  This is the reverse of the residual block
  """

  x = BatchNormalization()(inputs)
  x = Activation(activation)(x)

  conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides,
                    padding='same', kernel_initializer='he_normal')
  x = conv(x)
  
  return x

# %%
def dense_layer(x,num_ch=16):

    drop_rate = .1
    ## bottleneck layer Conv 1x1
    y = dense_unit(inputs=x, num_channels=num_ch,
                    kernel_size=1, batch_normalization=True)
  
    ## conv 3x3
    y = dense_unit(inputs=y, num_channels=num_ch,
                    kernel_size=3, batch_normalization=True)
    x = Concatenate()([y, x])
    x = SpatialDropout2D(drop_rate)(x)
    return x

# %%
def Transition_layer(inputs, num_channels=16, kernel_size=1,
                 strides=1):
   conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides,
                 padding='same', kernel_initializer='he_normal')
   x = conv(inputs)
   x = AveragePooling2D(2, strides=2)(x)
   return x

# %%
def dense_net(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
  
    num_ch = 16
    inputs = Input(shape=input_shape)

    # Add data augmentation as layers
    x = RandomFlip(mode = "horizontal")(inputs)

    ## Initial Layers
    conv = Conv2D(num_ch, kernel_size=7, strides=2,
                 padding='same', kernel_initializer='he_normal')
    x = conv(x)
    x = MaxPooling2D(3, strides=2)(x)


    ## Dense Block 1:  dense_layer x 2
    x = dense_layer(x,num_ch)
    counter = 1
    while counter < 2:
      num_ch = num_ch * (counter+1)
      x = dense_layer(x,num_ch)
      counter+=1

    ## Transition layer 1
    x = Transition_layer(x,num_ch)


    ## Dense Block 2:  dense_layer x 4
    counter = 1
    num_ch = 16
    while counter < 5:
      num_ch = num_ch * counter
      x = dense_layer(x,num_ch)
      counter+=1
    ## Transition layer 2
    x = Transition_layer(x)


    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                      activation='softmax',
                      kernel_initializer='he_normal')(x)

      # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
input_shape = (32,32,3)
model = dense_net(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()

# Uncomment the following line to plot the model visually - warning this may be quite large!
keras.utils.plot_model(model, dpi=48)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  random_flip_1 (RandomFlip)     (None, 32, 32, 3)    0           ['input_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 16)   2368        ['random_flip_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 7, 7, 16)     0           ['conv2d_15[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 16)    64          ['max_pooling2d[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 7, 7, 16)     0           ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 16)     272         ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 7, 7, 16)    64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 7, 7, 16)     0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 16)     2320        ['activation_13[0][0]']
#
#  concatenate (Concatenate)      (None, 7, 7, 32)     0           ['conv2d_17[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  spatial_dropout2d_6 (SpatialDr  (None, 7, 7, 32)    0           ['concatenate[0][0]']
#  opout2D)
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 32)    128         ['spatial_dropout2d_6[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 32)     1056        ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 7, 7, 32)    128         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 32)     9248        ['activation_15[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 7, 7, 64)     0           ['conv2d_19[0][0]',
#                                                                   'spatial_dropout2d_6[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 7, 7, 64)    0           ['concatenate_1[0][0]']
#  opout2D)
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 32)     2080        ['spatial_dropout2d_7[0][0]']
#
#  average_pooling2d (AveragePool  (None, 3, 3, 32)    0           ['conv2d_20[0][0]']
#  ing2D)
#
#  batch_normalization_18 (BatchN  (None, 3, 3, 32)    128         ['average_pooling2d[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 3, 3, 32)     0           ['batch_normalization_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 3, 3, 16)     528         ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 3, 3, 16)    64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 3, 3, 16)     0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 3, 3, 16)     2320        ['activation_17[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 3, 3, 48)     0           ['conv2d_22[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 3, 3, 48)    0           ['concatenate_2[0][0]']
#  opout2D)
#
#  batch_normalization_20 (BatchN  (None, 3, 3, 48)    192         ['spatial_dropout2d_8[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 3, 3, 48)     0           ['batch_normalization_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 3, 3, 32)     1568        ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 3, 3, 32)    128         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 3, 3, 32)     0           ['batch_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 3, 3, 32)     9248        ['activation_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 3, 3, 80)     0           ['conv2d_24[0][0]',
#                                                                   'spatial_dropout2d_8[0][0]']
#
#  spatial_dropout2d_9 (SpatialDr  (None, 3, 3, 80)    0           ['concatenate_3[0][0]']
#  opout2D)
#
#  batch_normalization_22 (BatchN  (None, 3, 3, 80)    320         ['spatial_dropout2d_9[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 3, 3, 80)     0           ['batch_normalization_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 3, 3, 96)     7776        ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 3, 3, 96)    384         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 3, 3, 96)     0           ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 3, 3, 96)     83040       ['activation_21[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 3, 3, 176)    0           ['conv2d_26[0][0]',
#                                                                   'spatial_dropout2d_9[0][0]']
#
#  spatial_dropout2d_10 (SpatialD  (None, 3, 3, 176)   0           ['concatenate_4[0][0]']
#  ropout2D)
#
#  batch_normalization_24 (BatchN  (None, 3, 3, 176)   704         ['spatial_dropout2d_10[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 3, 3, 176)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 3, 3, 384)    67968       ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 3, 3, 384)   1536        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 3, 3, 384)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 3, 3, 384)    1327488     ['activation_23[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 3, 3, 560)    0           ['conv2d_28[0][0]',
#                                                                   'spatial_dropout2d_10[0][0]']
#
#  spatial_dropout2d_11 (SpatialD  (None, 3, 3, 560)   0           ['concatenate_5[0][0]']
#  ropout2D)
#
#  conv2d_29 (Conv2D)             (None, 3, 3, 16)     8976        ['spatial_dropout2d_11[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 16)    0           ['conv2d_29[0][0]']
#  oling2D)
#
#  global_average_pooling2d_2 (Gl  (None, 16)          0           ['average_pooling2d_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 10)           170         ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,530,266
# Trainable params: 1,528,346
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
epochs = 50
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=val_dataset)
# Out:
# 1407/1407 [==============================] - 36s 26ms/step - loss: 1.6709 - accuracy: 0.3909 - val_loss: 1.4992 - val_accuracy: 0.4407

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.63      0.42      0.50       337
#   automobile       0.71      0.42      0.53       338
#         bird       0.31      0.37      0.34       306
#          cat       0.36      0.09      0.14       323
#         deer       0.49      0.18      0.26       297
#          dog       0.44      0.44      0.44       325
#         frog       0.31      0.89      0.46       307
#        horse       0.67      0.41      0.51       317
#         ship       0.47      0.76      0.58       326
#        truck       0.56      0.53      0.55       324
#
#     accuracy                           0.45      3200
#    macro avg       0.50      0.45      0.43      3200
# weighted avg       0.50      0.45      0.43      3200

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1
# Out:
# (32, 10)
# (32,)
# Predictions:
#  [3 1 6 8 5 9 7 8 2 2 7 4 9 1 2 7 0 8 7 6 6 6 5 6 8 8 2 8 6 8 6 0]

# %% [markdown]
# # Please Leave a note here explaining your approach/results for the e-moderator.

# %% [markdown]
# ##**ResNet**
# For the ResNet, I tried a multitude of combinations.
# Mostly the issue laid with overfitting the training set.
# With just the model, no dropout or data augmentation, the testset accuracy was approx. 80%. The introduction of spatialDropout (which drops a channel rather than a node) this increased the accuracy above 80% mark regularly. A dropout of .1 increased the accuracy to 81-82%. Then the introduction of the squeeze excite which can improve models by up 10% increased the accuracy to 84-85%, intermittenly the model would reach 85% but never above.
#
# When looking at the training set it was still overfitting even with the use of a drop out layer. To counteract this I introduced RandomFlip to create a data augmentation layer. This prevented overfitting, and increased the accuracy to 88% accuracy on the testset.
#
# My resNet follows the ResNet-18 design but makes the adjust. Reducing the blocks to 14 rather than 18. Also dropout layer and data augmentation layer were added resulting in 700k params.
#
# Next I examined a DenseNet
# ## **DenseNet**
# For the DenseNet I followed the design of the DenseNet-121, the smaller of the published DenseNets.
# I tried creating 4 Dense blocks, but I ran into issues here as the params were exceeding memory availability. So I reduced this to 3 layers and filters and found that the params were 39 million. This made the compilation time for 1 epoch 25mins rather than secs with the ResNet.
# To see if the DenseNet was viable for this task I had to reduce it down to 2 blocks with 2 and 4 layers in each which creates a 1.5million params. I didn't try more as memory might become an issue and I wanted to keep the DenseNet params low to get a comparision to the ResNet.
#
# Initially the DenseNet overfitted similar to the ResNet but with the introduction of spatialDropout and and RandomFlip for data augmentation, this prevented this the issue. More epochs were needed to reach a resonable accuracy.
#
# ## **Discussion on common parameters and layers**
# - 3x3 kernel were used in the Resnet and dense layers as larger receptive fields lead to larger convolutions.
# - 1x1 bottlenecks are also used to reduce dimensionality and required computation.
# - By reducing the layers and primarly using relu activation vanishing gradient descent was avoided but increases exploding gradient.
# - Batch normalization avoided exploding gradient and improved training time with a higher learning rate.
# - Global average pooling reduced feature maps size and reduced the necessity for several fully connected layers.
#
# ## **Comparison**
# Although published papers do show that the DenseNet outperforms the ResNet, in this paper I found that the ResNet seems  to outperform the DenseNet. This would be to the size of the Nets, as I had to reduce them down to fit the task.
# I would recommend the ResNet over the DenseNet for this instance. As the model achieved accuracy within 25 epochs half, and has a better accuracy.
#
# Epoch time for ResNet (700k params) : 32s| Accuracy: 87-88%
# Epoch time for DenseNet (1.5mill params): 32s | Accuracy: 76-78%
#
# ## **In summary**
# For further study into these Models, I would try test the DenseNet with lower amount of filters(channels). From this the number of blocks can be increased and potentially lead to a better performing model.
# For the ResNet, optimizing the layers would be the next step, removing dropouts here and there. The model achieved above 85% accuracy which was the goal, so reducing the size of the model might be a perferred action to take.
